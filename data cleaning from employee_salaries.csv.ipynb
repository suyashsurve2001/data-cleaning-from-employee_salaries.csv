# %%
'''import warnings
warnings.filterwarnings('ignore')'''
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('employee_salaries.csv')

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                0.0     400184.25           NaN  567595.43         567595.43
# 1          245131.88     137811.38           NaN  538909.28         538909.28
# 2          106088.18       16452.6           NaN  335279.91         335279.91
# 3           56120.71      198306.9           NaN  332343.61         332343.61
# 4             9737.0     182234.59           NaN  326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year  Notes         Agency Status
# 0       2011    NaN  San Francisco    NaN
# 1       2011    NaN  San Francisco    NaN
# 2       2011    NaN  San Francisco    NaN
# 3       2011    NaN  San Francisco    NaN
# 4       2011    NaN  San Francisco    NaN
# ...      ...    ...            ...    ...
# 148649  2014    NaN  San Francisco     PT
# 148650  2014    NaN  San Francisco    NaN
# 148651  2014    NaN  San Francisco    NaN
# 148652  2014    NaN  San Francisco    NaN
# 148653  2014    NaN  San Francisco     PT
#
# [148654 rows x 13 columns]

# %%
df.isnull().sum()/148654
# Out:
# Id                  0.000000
# EmployeeName        0.000000
# JobTitle            0.000000
# BasePay             0.004070
# OvertimePay         0.000000
# OtherPay            0.000000
# Benefits            0.243243
# TotalPay            0.000000
# TotalPayBenefits    0.000000
# Year                0.000000
# Notes               1.000000
# Agency              0.000000
# Status              0.743572
# dtype: float64

# %%
df.drop(columns=['Benefits','Notes','Status'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                    0
# EmployeeName          0
# JobTitle              0
# BasePay             605
# OvertimePay           0
# OtherPay              0
# TotalPay              0
# TotalPayBenefits      0
# Year                  0
# Agency                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay   TotalPay  TotalPayBenefits  Year  \
# 0                0.0     400184.25  567595.43         567595.43  2011
# 1          245131.88     137811.38  538909.28         538909.28  2011
# 2          106088.18       16452.6  335279.91         335279.91  2011
# 3           56120.71      198306.9  332343.61         332343.61  2011
# 4             9737.0     182234.59  326373.19         326373.19  2011
# ...              ...           ...        ...               ...   ...
# 148649             0             0       0.00              0.00  2014
# 148650  Not Provided  Not Provided       0.00              0.00  2014
# 148651  Not Provided  Not Provided       0.00              0.00  2014
# 148652  Not Provided  Not Provided       0.00              0.00  2014
# 148653             0       -618.13    -618.13           -618.13  2014
#
#                Agency
# 0       San Francisco
# 1       San Francisco
# 2       San Francisco
# 3       San Francisco
# 4       San Francisco
# ...               ...
# 148649  San Francisco
# 148650  San Francisco
# 148651  San Francisco
# 148652  San Francisco
# 148653  San Francisco
#
# [148049 rows x 10 columns]

# %%
df.JobTitle.value_counts()
# Out:
# Transit Operator                                 6975
# Special Nurse                                    4382
# Registered Nurse                                 3725
# Public Svc Aide-Public Works                     2514
# Police Officer 3                                 2411
#                                                  ...
# SENIOR MAINTENANCE CONTROLLER                       1
# LEGISLATIVE ASSISTANT, CITY ATTORNEY'S OFFICE       1
# SUPERVISING PARTS STOREKEEPER                       1
# SHELTER OFFICE ASSISTANT SUPERVISOR                 1
# POWERHOUSE ELECTRICIAN SUPERVISOR II                1
# Name: JobTitle, Length: 2155, dtype: int64

# %%
df.Year.value_counts()
# Out:
# 2014    38123
# 2013    37001
# 2012    36766
# 2011    36159
# Name: Year, dtype: int64

# %%
df.Agency.value_counts()
# Out:
# San Francisco    148049
# Name: Agency, dtype: int64

# %%
df=df[['EmployeeName','BasePay','OvertimePay','OtherPay','TotalPay']]

# %%
df
# Out:
#              EmployeeName       BasePay   OvertimePay      OtherPay   TotalPay
# 0          NATHANIEL FORD     167411.18           0.0     400184.25  567595.43
# 1            GARY JIMENEZ     155966.02     245131.88     137811.38  538909.28
# 2          ALBERT PARDINI     212739.13     106088.18       16452.6  335279.91
# 3       CHRISTOPHER CHONG       77916.0      56120.71      198306.9  332343.61
# 4         PATRICK GARDNER      134401.6        9737.0     182234.59  326373.19
# ...                   ...           ...           ...           ...        ...
# 148649      Roy I Tillery             0             0             0       0.00
# 148650       Not provided  Not Provided  Not Provided  Not Provided       0.00
# 148651       Not provided  Not Provided  Not Provided  Not Provided       0.00
# 148652       Not provided  Not Provided  Not Provided  Not Provided       0.00
# 148653          Joe Lopez             0             0       -618.13    -618.13
#
# [148049 rows x 5 columns]

# %%
df=df[['BasePay','OvertimePay','OtherPay','TotalPay']]

# %%
df
# Out:
#              BasePay   OvertimePay      OtherPay   TotalPay
# 0          167411.18           0.0     400184.25  567595.43
# 1          155966.02     245131.88     137811.38  538909.28
# 2          212739.13     106088.18       16452.6  335279.91
# 3            77916.0      56120.71      198306.9  332343.61
# 4           134401.6        9737.0     182234.59  326373.19
# ...              ...           ...           ...        ...
# 148649             0             0             0       0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00
# 148653             0             0       -618.13    -618.13
#
# [148049 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148049 entries, 0 to 148653
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   BasePay      148049 non-null  object
#  1   OvertimePay  148049 non-null  object
#  2   OtherPay     148049 non-null  object
#  3   TotalPay     148049 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 5.6+ MB

# %%
df.BasePay.unique()
# Out:
# array([167411.18, 155966.02, 212739.13, ..., '6.04', '15.5',
#        'Not Provided'], dtype=object)

# %%
df.BasePay.replace('Not Provided',np.nan)
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3           77916.0
# 4          134401.6
#             ...
# 148649            0
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653            0
# Name: BasePay, Length: 148049, dtype: object

# %%
df.BasePay=pd.to_numeric(df.BasePay,errors='coerce')

# %%
df
# Out:
#           BasePay   OvertimePay      OtherPay   TotalPay
# 0       167411.18           0.0     400184.25  567595.43
# 1       155966.02     245131.88     137811.38  538909.28
# 2       212739.13     106088.18       16452.6  335279.91
# 3        77916.00      56120.71      198306.9  332343.61
# 4       134401.60        9737.0     182234.59  326373.19
# ...           ...           ...           ...        ...
# 148649       0.00             0             0       0.00
# 148650        NaN  Not Provided  Not Provided       0.00
# 148651        NaN  Not Provided  Not Provided       0.00
# 148652        NaN  Not Provided  Not Provided       0.00
# 148653       0.00             0       -618.13    -618.13
#
# [148049 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148049 entries, 0 to 148653
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   BasePay      148045 non-null  float64
#  1   OvertimePay  148045 non-null  float64
#  2   OtherPay     148049 non-null  object
#  3   TotalPay     148049 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 5.6+ MB

# %%
df.OvertimePay.unique()
# Out:
# array([0.0, 245131.88, 106088.18, ..., '102.7', '56.77', 'Not Provided'],
#       dtype=object)

# %%
df.OvertimePay=pd.to_numeric(df.OvertimePay,errors='coerce')

# %%
df.OtherPay.unique()
# Out:
# array([400184.25, 137811.38, 16452.6, ..., '13.35', 'Not Provided',
#        '-618.13'], dtype=object)

# %%
df.OtherPay=pd.to_numeric(df.OtherPay,errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148049 entries, 0 to 148653
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   BasePay      148045 non-null  float64
#  1   OvertimePay  148045 non-null  float64
#  2   OtherPay     148045 non-null  float64
#  3   TotalPay     148049 non-null  float64
# dtypes: float64(4)
# memory usage: 5.6 MB

# %%
df
# Out:
#           BasePay  OvertimePay   OtherPay   TotalPay
# 0       167411.18         0.00  400184.25  567595.43
# 1       155966.02    245131.88  137811.38  538909.28
# 2       212739.13    106088.18   16452.60  335279.91
# 3        77916.00     56120.71  198306.90  332343.61
# 4       134401.60      9737.00  182234.59  326373.19
# ...           ...          ...        ...        ...
# 148649       0.00         0.00       0.00       0.00
# 148650        NaN          NaN        NaN       0.00
# 148651        NaN          NaN        NaN       0.00
# 148652        NaN          NaN        NaN       0.00
# 148653       0.00         0.00    -618.13    -618.13
#
# [148049 rows x 4 columns]

# %%
df.isnull()
# Out:
#         BasePay  OvertimePay  OtherPay  TotalPay
# 0         False        False     False     False
# 1         False        False     False     False
# 2         False        False     False     False
# 3         False        False     False     False
# 4         False        False     False     False
# ...         ...          ...       ...       ...
# 148649    False        False     False     False
# 148650     True         True      True     False
# 148651     True         True      True     False
# 148652     True         True      True     False
# 148653    False        False     False     False
#
# [148049 rows x 4 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#           BasePay  OvertimePay   OtherPay   TotalPay
# 0       167411.18         0.00  400184.25  567595.43
# 1       155966.02    245131.88  137811.38  538909.28
# 2       212739.13    106088.18   16452.60  335279.91
# 3        77916.00     56120.71  198306.90  332343.61
# 4       134401.60      9737.00  182234.59  326373.19
# ...           ...          ...        ...        ...
# 148645       0.00         0.00       0.00       0.00
# 148647       0.00         0.00       0.00       0.00
# 148648       0.00         0.00       0.00       0.00
# 148649       0.00         0.00       0.00       0.00
# 148653       0.00         0.00    -618.13    -618.13
#
# [148045 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148045 entries, 0 to 148653
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   BasePay      148045 non-null  float64
#  1   OvertimePay  148045 non-null  float64
#  2   OtherPay     148045 non-null  float64
#  3   TotalPay     148045 non-null  float64
# dtypes: float64(4)
# memory usage: 5.6 MB

# %%
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       TotalPay
# count  146736.000000   71324.000000  106731.000000  147968.000000
# mean    66917.130321   10558.389065    5056.916232   75096.914039
# std     42491.578949   14678.479153    9059.225070   50393.774930
# min         6.040000       0.020000       0.300000       0.300000
# 25%     35411.025000    1587.190000     624.000000   37075.577500
# 50%     65258.010000    5048.865000    2002.890000   71666.350000
# 75%     94984.072500   13360.790000    6274.455000  106062.822500
# max    319275.010000  245131.880000  400184.250000  567595.430000

# %%
df=df[df>0]

# %%
df.isnull().sum()
# Out:
# BasePay         1309
# OvertimePay    76721
# OtherPay       41314
# TotalPay          77
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#           BasePay  OvertimePay   OtherPay   TotalPay
# 1       155966.02    245131.88  137811.38  538909.28
# 2       212739.13    106088.18   16452.60  335279.91
# 3        77916.00     56120.71  198306.90  332343.61
# 4       134401.60      9737.00  182234.59  326373.19
# 5       118602.00      8601.00  189082.74  316285.74
# ...           ...          ...        ...        ...
# 147467    1182.12       487.38      44.03    1713.53
# 147535    1160.08       426.15      15.15    1601.38
# 147658    1282.97        36.66      49.85    1369.48
# 147659     426.44       273.24     431.56    1131.24
# 147689     365.68       705.24      12.19    1083.11
#
# [64311 rows x 4 columns]

# %%
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       TotalPay
# count   64311.000000   64311.000000   64311.000000   64311.000000
# mean    77011.308739   11376.903410    6446.812667   94835.024816
# std     33783.047127   15095.864216    9325.977115   46127.006918
# min        31.360000       0.020000       0.590000     192.430000
# 25%     55026.010000    2002.895000    1170.135000   62242.995000
# 50%     70547.000000    5798.180000    3739.980000   87419.480000
# 75%    104050.425000   14660.640000    8636.530000  125704.520000
# max    318835.490000  245131.880000  203735.920000  538909.280000

# %%
plt.hist(df.BasePay)
# Out:
# (array([5.5000e+03, 1.8650e+04, 2.1291e+04, 1.4188e+04, 4.1790e+03,
#         3.8400e+02, 9.8000e+01, 1.4000e+01, 6.0000e+00, 1.0000e+00]),
#  array([3.13600000e+01, 3.19117730e+04, 6.37921860e+04, 9.56725990e+04,
#         1.27553012e+05, 1.59433425e+05, 1.91313838e+05, 2.23194251e+05,
#         2.55074664e+05, 2.86955077e+05, 3.18835490e+05]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
# (array([5.5764e+04, 6.2910e+03, 1.6600e+03, 4.5700e+02, 1.0000e+02,
#         2.8000e+01, 5.0000e+00, 3.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([2.00000000e-02, 2.45132060e+04, 4.90263920e+04, 7.35395780e+04,
#         9.80527640e+04, 1.22565950e+05, 1.47079136e+05, 1.71592322e+05,
#         1.96105508e+05, 2.20618694e+05, 2.45131880e+05]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
# (array([6.1621e+04, 2.1870e+03, 2.1200e+02, 9.3000e+01, 8.5000e+01,
#         6.6000e+01, 2.9000e+01, 9.0000e+00, 5.0000e+00, 4.0000e+00]),
#  array([5.90000000e-01, 2.03741230e+04, 4.07476560e+04, 6.11211890e+04,
#         8.14947220e+04, 1.01868255e+05, 1.22241788e+05, 1.42615321e+05,
#         1.62988854e+05, 1.83362387e+05, 2.03735920e+05]),
#  <BarContainer object of 10 artists>)

# %%
mini=df.quantile(0.2)
maxi=df.quantile(0.8)

# %%
df=df[(df>mini)&(df>maxi)]

# %%
df
# Out:
#           BasePay  OvertimePay   OtherPay   TotalPay
# 1       155966.02    245131.88  137811.38  538909.28
# 2       212739.13    106088.18   16452.60  335279.91
# 3             NaN     56120.71  198306.90  332343.61
# 4       134401.60          NaN  182234.59  326373.19
# 5       118602.00          NaN  189082.74  316285.74
# ...           ...          ...        ...        ...
# 147467        NaN          NaN        NaN        NaN
# 147535        NaN          NaN        NaN        NaN
# 147658        NaN          NaN        NaN        NaN
# 147659        NaN          NaN        NaN        NaN
# 147689        NaN          NaN        NaN        NaN
#
# [64311 rows x 4 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#           BasePay  OvertimePay   OtherPay   TotalPay
# 1       155966.02    245131.88  137811.38  538909.28
# 2       212739.13    106088.18   16452.60  335279.91
# 8       176932.64     86362.68   40132.23  303427.55
# 10      194999.39     71344.88   33149.90  299494.17
# 14      174872.64     74050.30   37424.11  286347.05
# ...           ...          ...        ...        ...
# 114914  112164.00     18643.76   13319.43  144127.19
# 114983  112674.02     18923.20   11787.88  143385.10
# 115003  112164.02     20525.21   10669.64  143358.87
# 115077  112164.02     19498.14   10818.49  142480.65
# 118945  114573.05     19895.67   15986.66  150455.38
#
# [3085 rows x 4 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#        index    BasePay  OvertimePay   OtherPay   TotalPay
# 0          1  155966.02    245131.88  137811.38  538909.28
# 1          2  212739.13    106088.18   16452.60  335279.91
# 2          8  176932.64     86362.68   40132.23  303427.55
# 3         10  194999.39     71344.88   33149.90  299494.17
# 4         14  174872.64     74050.30   37424.11  286347.05
# ...      ...        ...          ...        ...        ...
# 3080  114914  112164.00     18643.76   13319.43  144127.19
# 3081  114983  112674.02     18923.20   11787.88  143385.10
# 3082  115003  112164.02     20525.21   10669.64  143358.87
# 3083  115077  112164.02     19498.14   10818.49  142480.65
# 3084  118945  114573.05     19895.67   15986.66  150455.38
#
# [3085 rows x 5 columns]

# %%
df.shape
# Out:
# (3085, 5)

# %%
df.describe()
# Out:
#                index        BasePay    OvertimePay       OtherPay  \
# count    3085.000000    3085.000000    3085.000000    3085.000000
# mean    68381.545543  127366.182464   43088.665569   18932.528392
# std     36643.306363   16687.040699   22190.338535    8187.968328
# min         1.000000  110224.150000   18088.990000   10400.020000
# 25%     37617.000000  115893.460000   25795.830000   14868.470000
# 50%     74011.000000  123105.010000   37790.130000   17824.110000
# 75%    111012.000000  135512.000000   53861.780000   20821.020000
# max    118945.000000  272855.510000  245131.880000  180516.680000
#
#             TotalPay
# count    3085.000000
# mean   189387.376425
# std     31319.355169
# min    141336.300000
# 25%    167200.410000
# 50%    183167.530000
# 75%    204420.180000
# max    538909.280000

# %%
plt.hist(df.BasePay)
# Out:
# (array([1.688e+03, 9.660e+02, 2.940e+02, 4.700e+01, 6.900e+01, 1.200e+01,
#         7.000e+00, 0.000e+00, 1.000e+00, 1.000e+00]),
#  array([110224.15 , 126487.286, 142750.422, 159013.558, 175276.694,
#         191539.83 , 207802.966, 224066.102, 240329.238, 256592.374,
#         272855.51 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.OvertimePay	)
# Out:
# (array([1.713e+03, 8.750e+02, 3.510e+02, 9.900e+01, 3.700e+01, 6.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00]),
#  array([ 18088.99 ,  40793.279,  63497.568,  86201.857, 108906.146,
#         131610.435, 154314.724, 177019.013, 199723.302, 222427.591,
#         245131.88 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.OtherPay)
# Out:
# (array([2.843e+03, 2.110e+02, 2.000e+01, 6.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 3.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 10400.02 ,  27411.686,  44423.352,  61435.018,  78446.684,
#          95458.35 , 112470.016, 129481.682, 146493.348, 163505.014,
#         180516.68 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.TotalPay)
# Out:
# (array([1.434e+03, 1.231e+03, 3.270e+02, 6.600e+01, 2.400e+01, 2.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([141336.3  , 181093.598, 220850.896, 260608.194, 300365.492,
#         340122.79 , 379880.088, 419637.386, 459394.684, 499151.982,
#         538909.28 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df)
# Out:
# (array([[1.103e+03, 1.052e+03, 9.300e+02, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 2.950e+03, 1.330e+02, 1.000e+00, 1.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [2.314e+03, 7.230e+02, 4.400e+01, 2.000e+00, 2.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [3.068e+03, 1.200e+01, 4.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [0.000e+00, 0.000e+00, 5.280e+02, 2.041e+03, 4.420e+02, 6.200e+01,
#          1.100e+01, 0.000e+00, 0.000e+00, 1.000e+00]]),
#  array([1.00000000e+00, 5.38918280e+04, 1.07782656e+05, 1.61673484e+05,
#         2.15564312e+05, 2.69455140e+05, 3.23345968e+05, 3.77236796e+05,
#         4.31127624e+05, 4.85018452e+05, 5.38909280e+05]),
#  <a list of 5 BarContainer objects>)
